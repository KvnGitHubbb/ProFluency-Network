# %% [markdown]
# <span style="color:red;">Create both the dependent and independent variables </span>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h1>All Stocks</h1>

# %%
"""
All 1193 stocks 
Keep only the tickers that have full observations and no 0's
Observations are from 01-2013 to 12-2022
Format: datum, metric, ticke
"""
all_stocks = pd.read_excel('z_features.xlsx', sheet_name='test_set')
all_stocks = all_stocks['Symbol']
all_stocks = set(all_stocks)
all_stocks
# Out:
# {'RBA',
#  'TRC',
#  'CCU',
#  'KMB',
#  'OLP',
#  'PAR',
#  'EDU',
#  'PNW',
#  'WOR',
#  'ESS',
#  'CRM',
#  'HVT',
#  'HIW',
#  'NRT',
#  'CCRD',
#  'CIA',
#  'ACRE',
#  'MCK',
#  'CLH',
#  'SUI',
#  'FNV',
#  'OLN',
#  'HCI',
#  'TISI',
#  'CUBE',
#  'TK',
#  'KBH',
#  'AGO',
#  'KMI',
#  'NCR',
#  'KFS',
#  'SLG',
#  'OGE',
#  'TNC',
#  'EME',
#  'BFS',
#  'AVB',
#  'CIG',
#  'CL',
#  'TDC',
#  'BBVA',
#  'CCJ',
#  'YELP',
#  'ALV',
#  'ING',
#  'FAF',
#  'BFH',
#  'SLCA',
#  'SHO',
#  'CAG',
#  'LEG',
#  'CSR',
#  'M',
#  'TMO',
#  'SMG',
#  'BAC',
#  'MTX',
#  'CPG',
#  'GPN',
#  'MCO',
#  'NSC',
#  'FLR',
#  'CYH',
#  'UNP',
#  'CACI',
#  'XPO',
#  'CNC',
#  'EIX',
#  'DAR',
#  'MOD',
#  'AEG',
#  'HUM',
#  'VALE',
#  'KB',
#  'CRI',
#  'NVO',
#  'G',
#  'ZWS',
#  'TTE',
#  'UTL',
#  'ORA',
#  'TNP',
#  'WGO',
#  'INT',
#  'EHC',
#  'RES',
#  'CEQP',
#  'AZO',
#  'CADE',
#  'DRI',
#  'EW',
#  'LRN',
#  'WF',
#  'NNN',
#  'WSO',
#  'TFII',
#  'JBT',
#  'TECK',
#  'SF',
#  'GME',
#  'ACR',
#  'BIO',
#  'ABB',
#  'BHC',
#  'DRQ',
#  'RIG',
#  'SCHW',
#  'GCO',
#  'CMS',
#  'SCL',
#  'ORAN',
#  'SXT',
#  'HRB',
#  'FSM',
#  'POR',
#  'PPG',
#  'CHT',
#  'STNG',
#  'EPAM',
#  'DSX',
#  'UMH',
#  'AIT',
#  'RGA',
#  'CPK',
#  'NBHC',
#  'THC',
#  'CMRE',
#  'HIG',
#  'MAC',
#  'FCF',
#  'ITUB',
#  'CMI',
#  'CDE',
#  'VFC',
#  'SLB',
#  'UMC',
#  'BCH',
#  'TS',
#  'DEI',
#  'MCS',
#  'RSG',
#  'TLK',
#  'MPX',
#  'BHE',
#  'SNDA',
#  'TREX',
#  'WSR',
#  'AWR',
#  'VGR',
#  'BBY',
#  'MFC',
#  'CBZ',
#  'MCD',
#  'SSD',
#  'UVE',
#  'MKC',
#  'PKX',
#  'MMP',
#  'ENV',
#  'RWT',
#  'MG',
#  'DOOR',
#  'A',
#  'KRO',
#  'SQM',
#  'EXR',
#  'BKH',
#  'CRH',
#  'QUAD',
#  'MHO',
#  'USB',
#  'GNRC',
#  'OXY',
#  'UHT',
#  'SRE',
#  'PEB',
#  'CPA',
#  'BKD',
#  'AUY',
#  'ARCO',
#  'CNA',
#  'PFS',
#  'NI',
#  'DECK',
#  'TGS',
#  'DCO',
#  'DPZ',
#  'WIT',
#  'GTN',
#  'KOP',
#  'GMED',
#  'SBSW',
#  'ARC',
#  'PRGO',
#  'RRC',
#  'AIR',
#  'VET',
#  'WAL',
#  'BBAR',
#  'DLB',
#  'AUD',
#  'CBU',
#  'NR',
#  'DE',
#  'ORN',
#  'PPL',
#  'EVRI',
#  'AXL',
#  'NS',
#  'EXP',
#  'WTRG',
#  'EQC',
#  'TPL',
#  'ACN',
#  'ETR',
#  'LXU',
#  'CLF',
#  'PKG',
#  'HD',
#  'BMY',
#  'LLY',
#  'BB',
#  'AON',
#  'FICO',
#  'GHL',
#  'HSY',
#  'UFI',
#  'MANU',
#  'KOS',
#  'WCC',
#  'VAC',
#  'F',
#  'GATX',
#  'AIG',
#  'GPS',
#  'TV',
#  'LMT',
#  'CCK',
#  'AXR',
#  'DAC',
#  'FL',
#  'FN',
#  'RGS',
#  'TEL',
#  'HOV',
#  'AIZ',
#  'TNL',
#  'ELS',
#  'EL',
#  'GGG',
#  'FUL',
#  'MTDR',
#  'SIG',
#  'UDR',
#  'ICE',
#  'FDX',
#  'CWT',
#  'UNF',
#  'TEX',
#  'DIS',
#  'LEN',
#  'BERY',
#  'AGM',
#  'LCII',
#  'GBX',
#  'BNS',
#  'K',
#  'AXS',
#  'INGR',
#  'GNTY',
#  'DVA',
#  'FHI',
#  'BWXT',
#  'AFL',
#  'BCE',
#  'BIG',
#  'FENG',
#  'PEAK',
#  'GOLD',
#  'DIN',
#  'PBI',
#  'NYT',
#  'DCI',
#  'DY',
#  'BRT',
#  'CPAC',
#  'EBF',
#  'EQNR',
#  'DBI',
#  'MSA',
#  'MED',
#  'DVN',
#  'AZZ',
#  'MTB',
#  'MGA',
#  'JWN',
#  'MUX',
#  'NUS',
#  'CFR',
#  'NPK',
#  'CBRE',
#  'RL',
#  'SYK',
#  'NGL',
#  'PRI',
#  'MET',
#  'RLI',
#  'AHT',
#  'BDX',
#  'EGP',
#  'FUN',
#  'HZO',
#  'LUMN',
#  'AAP',
#  'GPK',
#  'CAT',
#  'ABG',
#  'HRL',
#  'KMX',
#  'TRNO',
#  'BBWI',
#  'PDM',
#  'BCS',
#  'BYD',
#  'CW',
#  'VOC',
#  'HR',
#  'MLP',
#  'MAXR',
#  'EBS',
#  'COP',
#  'CVE',
#  'RE',
#  'V',
#  'BXP',
#  'AMRC',
#  'OPY',
#  'HUN',
#  'CPRI',
#  'FIS',
#  'NOC',
#  'IFF',
#  'DRH',
#  'BLDR',
#  'EGY',
#  'ERF',
#  'KIM',
#  'MTR',
#  'TOL',
#  'BALL',
#  'SAP',
#  'VPG',
#  'CALX',
#  'TTI',
#  'ALX',
#  'WU',
#  'AIN',
#  'NC',
#  'GS',
#  'PMT',
#  'PFE',
#  'D',
#  'BLX',
#  'HAE',
#  'ALE',
#  'MLM',
#  'VVI',
#  'FHN',
#  'NJR',
#  'SJW',
#  'TM',
#  'LPL',
#  'WPM',
#  'BR',
#  'DCP',
#  'NGVC',
#  'BEP',
#  'SWN',
#  'TRV',
#  'WRB',
#  'CNK',
#  'CNP',
#  'BWA',
#  'CBT',
#  'SM',
#  'SBS',
#  'PEG',
#  'RTX',
#  'SO',
#  'WTI',
#  'CPE',
#  'CUZ',
#  'BDC',
#  'AER',
#  'CUK',
#  'LYV',
#  'MPLX',
#  'UI',
#  'ED',
#  'MFA',
#  'PSA',
#  'ORI',
#  'IDT',
#  'TAC',
#  'IPG',
#  'SWX',
#  'MPC',
#  'TDS',
#  'TGI',
#  'YPF',
#  'BBD',
#  'CVX',
#  'BBDC',
#  'CGA',
#  'FCX',
#  'SFL',
#  'ASA',
#  'NEU',
#  'CNX',
#  'STAG',
#  'ENS',
#  'NLS',
#  'X',
#  'CMP',
#  'GIS',
#  'NEM',
#  'PBR',
#  'PSO',
#  'SR',
#  'BBW',
#  'PBF',
#  'ROK',
#  'CPS',
#  'HLF',
#  'DHT',
#  'ENZ',
#  'YUM',
#  'CX',
#  'AL',
#  'ATI',
#  'HES',
#  'KFY',
#  'SKY',
#  'NOW',
#  'TT',
#  'PKE',
#  'AVNT',
#  'CORR',
#  'VTOL',
#  'PG',
#  'ARW',
#  'SBH',
#  'IT',
#  'SPXC',
#  'RDY',
#  'EFC',
#  'ELV',
#  'NCLH',
#  'FSS',
#  'KBR',
#  'AMP',
#  'DDS',
#  'FTI',
#  'SRL',
#  'AJRD',
#  'DFS',
#  'ETD',
#  'GOL',
#  'IBM',
#  'KT',
#  'NNI',
#  'WES',
#  'NMR',
#  'ARL',
#  'MD',
#  'APO',
#  'BRFS',
#  'BRO',
#  'CIM',
#  'PRG',
#  'XIN',
#  'LOW',
#  'WTS',
#  'STC',
#  'SUN',
#  'ABC',
#  'ROP',
#  'CATO',
#  'OMI',
#  'PRO',
#  'UHS',
#  'ALEX',
#  'CTS',
#  'KEX',
#  'HWM',
#  'DTE',
#  'AOS',
#  'LSI',
#  'CODI',
#  'RYN',
#  'EVR',
#  'HPQ',
#  'DLR',
#  'CP',
#  'NWN',
#  'RPT',
#  'NUE',
#  'ITT',
#  'BPT',
#  'GWW',
#  'PGR',
#  'WAB',
#  'RJF',
#  'NSP',
#  'AN',
#  'KWR',
#  'PCG',
#  'SPH',
#  'DRD',
#  'STE',
#  'GGB',
#  'HXL',
#  'SNV',
#  'SONY',
#  'UL',
#  'FBIN',
#  'KMPR',
#  'BK',
#  'OHI',
#  'TBI',
#  'DINO',
#  'DHI',
#  'FE',
#  'LXP',
#  'PVH',
#  'WAT',
#  'EVC',
#  'MOV',
#  'EXPR',
#  'HPP',
#  'EXK',
#  'AKR',
#  'MTW',
#  'TGH',
#  'B',
#  'BF.B',
#  'LTC',
#  'IBN',
#  'BP',
#  'AGRO',
#  'EPC',
#  'MOS',
#  'TUP',
#  'WMT',
#  'TKR',
#  'XYL',
#  'PRU',
#  'TSM',
#  'ASGN',
#  'EGLE',
#  'MMS',
#  'SNA',
#  'DB',
#  'KSS',
#  'IRS',
#  'TEO',
#  'TCI',
#  'NKE',
#  'MPW',
#  'PHI',
#  'CI',
#  'RENN',
#  'APD',
#  'GLW',
#  'LAD',
#  'KORE',
#  'LNC',
#  'MSI',
#  'AIV',
#  'CRT',
#  'ALSN',
#  'BG',
#  'PGTI',
#  'RY',
#  'SHG',
#  'VMC',
#  'WMK',
#  'ASH',
#  'CIB',
#  'CPB',
#  'LUV',
#  'MKL',
#  'RNR',
#  'KR',
#  'UTI',
#  'POST',
#  'WWE',
#  'MTH',
#  'ALB',
#  'AROC',
#  'TX',
#  'TLYS',
#  'NPO',
#  'JBL',
#  'BCO',
#  'PAM',
#  'RGR',
#  'RHI',
#  'EOG',
#  'SMFG',
#  'BKE',
#  'SUP',
#  'FRO',
#  'TY',
#  'NLY',
#  'HSC',
#  'GLT',
#  'SXC',
#  'GFI',
#  'SPG',
#  'SIX',
#  'AU',
#  'TROX',
#  'MODG',
#  'HOUS',
#  'PKI',
#  'EPAC',
#  'VIPS',
#  'APTV',
#  'KGC',
#  'SAH',
#  'GBCI',
#  'CNS',
#  'SPLP',
#  'OKE',
#  'DKL',
#  'BKU',
#  'OSK',
#  'WEC',
#  'ATGE',
#  'OFG',
#  'CNI',
#  'BSX',
#  'QGEN',
#  'PH',
#  'AME',
#  'EQS',
#  'TRN',
#  'BAH',
#  'AFG',
#  'KRG',
#  'KW',
#  'LEA',
#  'STT',
#  'MA',
#  'GIB',
#  'WTM',
#  'SAN',
#  'SEE',
#  'XOM',
#  'DOV',
#  'JKS',
#  'SA',
#  'BAP',
#  'BRK.B',
#  'DHR',
#  'IX',
#  'MSM',
#  'FLO',
#  'NFG',
#  'SCI',
#  'GD',
#  'AWK',
#  'CYD',
#  'SNN',
#  'E',
#  'RPM',
#  'TAP',
#  'LAC',
#  'CS',
#  'BDN',
#  'WD',
#  'WEX',
#  'WOLF',
#  'RS',
#  'DEO',
#  'CMA',
#  'ONTO',
#  'ENB',
#  'TJX',
#  'UAN',
#  'ANF',
#  'ABBV',
#  'SON',
#  'WLK',
#  'GES',
#  'TFC',
#  'ARI',
#  'PNC',
#  'UGI',
#  'ABT',
#  'GNW',
#  'KOF',
#  'LNN',
#  'BMA',
#  'VSH',
#  'SCM',
#  'VHI',
#  'TRP',
#  'PBT',
#  'SYY',
#  'TYL',
#  'EDN',
#  'HLX',
#  'IIIN',
#  'MATX',
#  'NYCB',
#  'IEX',
#  'GRMN',
#  'CMC',
#  'RHP',
#  'TRI',
#  'WELL',
#  'THO',
#  'CPF',
#  'FTK',
#  'EQT',
#  'PVL',
#  'OVV',
#  'PLOW',
#  'PHG',
#  'TAL',
#  'AMT',
#  'IBA',
#  'CHS',
#  'GB',
#  'CIEN',
#  'SBR',
#  'STM',
#  'LCI',
#  'NBR',
#  'ATR',
#  'PLD',
#  'NHI',
#  'BXC',
#  'EQR',
#  'PWR',
#  'SU',
#  'MSCI',
#  'GVA',
#  'OII',
#  'RDN',
#  'JEF',
#  'AUB',
#  'HMN',
#  'RAD',
#  'FMC',
#  'MDC',
#  'MCY',
#  'KAMN',
#  'ROL',
#  'ARR',
#  'CVS',
#  'CNMD',
#  'STWD',
#  'VRE',
#  'CCI',
#  'CRK',
#  'HMY',
#  'IVZ',
#  'RCI',
#  'TKC',
#  'KAR',
#  'SKT',
#  'ESTE',
#  'HL',
#  'VTR',
#  'WM',
#  'FIX',
#  'HE',
#  'VATE',
#  'BKKT',
#  'KEY',
#  'ADM',
#  'BRC',
#  'GL',
#  'RM',
#  'APH',
#  'AWI',
#  'MAN',
#  'MTG',
#  'KKR',
#  'IPI',
#  'NAT',
#  'COF',
#  'DHX',
#  'HHC',
#  'TARO',
#  'ZBH',
#  'CMG',
#  'EPR',
#  'H',
#  'HDB',
#  'ATO',
#  'CCM',
#  'FLS',
#  'CE',
#  'MYE',
#  'CSL',
#  'GEO',
#  'EMR',
#  'SNX',
#  'UPS',
#  'BAX',
#  'TWI',
#  'SEM',
#  'EIG',
#  'SID',
#  'SQNS',
#  'NL',
#  'TTC',
#  'ASR',
#  'HY',
#  'FBP',
#  'BUD',
#  'SCS',
#  'CIR',
#  'VMI',
#  'CF',
#  'MBI',
#  'CLS',
#  'CHE',
#  'FMS',
#  'UNH',
#  'OFC',
#  'FLT',
#  'CXW',
#  'UGP',
#  'MRK',
#  'PB',
#  'IDA',
#  'TRGP',
#  'MTD',
#  'OCN',
#  'TD',
#  'LPX',
#  'CHD',
#  'CAL',
#  'NM',
#  'IMAX',
#  'HMC',
#  'NOK',
#  'SRT',
#  'FDP',
#  'GLP',
#  'GTLS',
#  'HII',
#  'HNI',
#  'IAG',
#  'PUK',
#  'SAM',
#  'TPX',
#  'VNO',
#  'WFC',
#  'AMN',
#  'MUR',
#  'TSN',
#  'HBI',
#  'UVV',
#  'VTLE',
#  'SSTK',
#  'KRC',
#  'SXI',
#  'HTH',
#  'LAZ',
#  'MX',
#  'GPC',
#  'WMB',
#  'ABR',
#  'FF',
#  'BLK',
#  'THG',
#  'NGS',
#  'WCN',
#  'DBD',
#  'AG',
#  'AVD',
#  'MTN',
#  'CPT',
#  'MLR',
#  'GHM',
#  'SJR',
#  'SCX',
#  'UAA',
#  'STZ',
#  'BC',
#  'ENLC',
#  'HP',
#  'CB',
#  'CR',
#  'DUK',
#  'BMO',
#  'LYG',
#  'FNB',
#  'TXT',
#  'ITGR',
#  'AES',
#  'NOA',
#  'AEO',
#  'FCN',
#  'OIS',
#  'SAR',
#  'ALG',
#  'BN',
#  'RH',
#  'AORT',
#  'AEL',
#  'MAS',
#  'CAH',
#  'SHW',
#  'TU',
#  'MEI',
#  'HSBC',
#  'NX',
#  'CVI',
#  'GWRE',
#  'MO',
#  'DX',
#  'BANC',
#  'MRO',
#  'EMN',
#  'FRC',
#  'L',
#  'SMP',
#  'INFY',
#  'GEF',
#  'JHX',
#  'HTGC',
#  'ESE',
#  'IRM',
#  'RCL',
#  'GRC',
#  'AAIC',
#  'AGX',
#  'MAIN',
#  'JNJ',
#  'PRA',
#  'GAM',
#  'HEI',
#  'NEE',
#  'FR',
#  'JCI',
#  'WWW',
#  'GEL',
#  'AYI',
#  'AEE',
#  'WST',
#  'KAI',
#  'CLB',
#  'FC',
#  'ET',
#  'EC',
#  'DAN',
#  'NOV',
#  'SJT',
#  'PM',
#  'HCA',
#  'SOL',
#  'MOH',
#  'AJG',
#  'GNE',
#  'ALL',
#  'KEP',
#  'BEN',
#  'PAG',
#  'ROG',
#  'R',
#  'FRT',
#  'DLX',
#  'GTY',
#  'BZH',
#  'PNM',
#  'CRS',
#  'STN',
#  'TG',
#  'THR',
#  'TNK',
#  'TPC',
#  'PXD',
#  'SAND          ',
#  'AKO.A',
#  'LII',
#  'DG',
#  'ETN',
#  'HI',
#  'PARR',
#  'SLF',
#  'CULP',
#  'UIS',
#  'ERJ',
#  ...}

# %% [markdown]
# <h1>Control General</h1>

# %%
"""
Most controls can be made by changing the file and variable names in the code below
"""
df = pd.read_excel('controls_full_no0\data_control_price.xlsx')
df

# %%
df = df[df['Ticker Symbol'].isin(all_stocks)] \
    .groupby('Ticker Symbol') \
    .filter(lambda x: len(x) == 120 and not x.isna().any().any() and not (x['Price - Close - Monthly'] == 0).any()) \
    .reset_index() \
    .drop('index', axis=1) 
df
# Out:
#        Data Date - Security Monthly  Price - Close - Monthly Ticker Symbol
# 0                        2013-01-31                    18.85           AIR
# 1                        2013-02-28                    17.57           AIR
# 2                        2013-03-31                    18.39           AIR
# 3                        2013-04-30                    17.86           AIR
# 4                        2013-05-31                    20.06           AIR
# ...                             ...                      ...           ...
# 140875                   2022-08-31                    83.00           LYB
# 140876                   2022-09-30                    75.28           LYB
# 140877                   2022-10-31                    76.45           LYB
# 140878                   2022-11-30                    85.01           LYB
# 140879                   2022-12-31                    83.03           LYB
#
# [140880 rows x 3 columns]

# %%
# check amount of observations
len(df)/120
# Out:
# 1174.0

# %%
# df['Price - Close - Monthly'] = 1 / df['Price - Close - Monthly']
# df
df.to_excel('controls_full_no0\data_filtered_control_price.xlsx')

# %% [markdown]
# <h1>Control Volatility</h1>

# %%
"""
Here we create the monthly volatility control variable
"""
df = pd.read_csv('controls_full_no0\data_control_volatility.txt', delimiter='\t')
df = df.drop(columns=['gvkey', 'iid']).rename(columns={'datadate': 'Date', 'tic': 'Ticker Symbol', 'prccd': 'Price'})
df['Daily Returns'] = df.groupby('Ticker Symbol')['Price'].pct_change()*100
df
# Out:
# C:\Users\538562gz\AppData\Local\Temp\ipykernel_9528\1935930405.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('controls_full_no0\data_control_volatility.txt', delimiter='\t')
#           gvkey iid    datadate  tic  prccd
# 0          1004  01  2013-01-02  AIR  19.37
# 1          1004  01  2013-01-03  AIR  19.82
# 2          1004  01  2013-01-04  AIR  20.11
# 3          1004  01  2013-01-07  AIR  19.75
# 4          1004  01  2013-01-08  AIR  19.61
# ...         ...  ..         ...  ...    ...
# 4386105  312009  01  2022-12-23  FRO  12.49
# 4386106  312009  01  2022-12-27  FRO  12.48
# 4386107  312009  01  2022-12-28  FRO  11.92
# 4386108  312009  01  2022-12-29  FRO  12.06
# 4386109  312009  01  2022-12-30  FRO  12.14
#
# [4386110 rows x 5 columns]

# %%
# group by both ticker and month, then calculate the volatility
df['Date'] = pd.to_datetime(df['Date']) 
monthly_volatility = df.groupby(['Ticker Symbol', pd.Grouper(key='Date', freq='M')])['Daily Returns'].std()
monthly_volatility
# Out:
# Ticker Symbol  Date
# 0050B          2013-02-28         NaN
#                2013-05-31         NaN
#                2013-08-31         NaN
#                2013-11-30         NaN
#                2014-02-28         NaN
#                                ...
# ZWS            2022-08-31    2.072921
#                2022-09-30    2.119668
#                2022-10-31    3.310613
#                2022-11-30    2.658288
#                2022-12-31    2.876602
# Name: Daily Returns, Length: 212090, dtype: float64

# %%
df_monthly_volatility = monthly_volatility.reset_index().rename(columns={'Daily Returns': 'Monthly Volatility'})
df = df_monthly_volatility
df
# Out:
#        Ticker Symbol       Date  Monthly Volatility
# 0              0050B 2013-02-28                 NaN
# 1              0050B 2013-05-31                 NaN
# 2              0050B 2013-08-31                 NaN
# 3              0050B 2013-11-30                 NaN
# 4              0050B 2014-02-28                 NaN
# ...              ...        ...                 ...
# 212085           ZWS 2022-08-31            2.072921
# 212086           ZWS 2022-09-30            2.119668
# 212087           ZWS 2022-10-31            3.310613
# 212088           ZWS 2022-11-30            2.658288
# 212089           ZWS 2022-12-31            2.876602
#
# [212090 rows x 3 columns]

# %%
df = df[df['Ticker Symbol'].isin(all_stocks)] \
    .groupby('Ticker Symbol') \
    .filter(lambda x: len(x) == 120 and not x.isna().any().any() and not (x['Monthly Volatility'] == 0).any()) \
    .reset_index() \
    .drop('index', axis=1) 
df
# Out:
#        Ticker Symbol       Date  Monthly Volatility
# 0                  A 2013-01-31            1.094107
# 1                  A 2013-02-28            1.662541
# 2                  A 2013-03-31            1.118800
# 3                  A 2013-04-30            1.841820
# 4                  A 2013-05-31            1.359981
# ...              ...        ...                 ...
# 140755           ZWS 2022-08-31            2.072921
# 140756           ZWS 2022-09-30            2.119668
# 140757           ZWS 2022-10-31            3.310613
# 140758           ZWS 2022-11-30            2.658288
# 140759           ZWS 2022-12-31            2.876602
#
# [140760 rows x 3 columns]

# %%
len(df)/120
# Out:
# 1173.0

# %%
df.to_excel('controls_full_no0\data_filtered_control_volatility.xlsx')

# %% [markdown]
# <h1>Control Size</h1>

# %%
"""
Here we create the monthly size control variable
"""
df = pd.read_excel('controls_full_no0\data_control_size.xlsx')
df['Market Capitalization'] = df['Price'] * df['Shares Outstanding Monthly']
# Out:
#        Data Date - Security Monthly Ticker Symbol  Price  \
# 0                        2013-01-31           AIR  18.85
# 1                        2013-02-28           AIR  17.57
# 2                        2013-03-31           AIR  18.39
# 3                        2013-04-30           AIR  17.86
# 4                        2013-05-31           AIR  20.06
# ...                             ...           ...    ...
# 157178                   2022-08-31           FRO  11.86
# 157179                   2022-09-30           FRO  10.93
# 157180                   2022-10-31           FRO  12.56
# 157181                   2022-11-30           FRO  13.83
# 157182                   2022-12-31           FRO  12.14
#
#         Shares Outstanding Monthly
# 0                       39708000.0
# 1                       39708000.0
# 2                       39733000.0
# 3                       39733000.0
# 4                       39733000.0
# ...                            ...
# 157178                 203531000.0
# 157179                 203531000.0
# 157180                 203531000.0
# 157181                 203531000.0
# 157182                 222623000.0
#
# [157183 rows x 4 columns]

# %%
df = df[df['Ticker Symbol'].isin(all_stocks)] \
    .groupby('Ticker Symbol') \
    .filter(lambda x: len(x) == 120 and not x.isna().any().any() and not (x['Market Capitalization'] == 0).any()) \
    .reset_index() \
    .drop('index', axis=1) 
df
# Out:
#        Data Date - Security Monthly Ticker Symbol  Price  \
# 0                        2013-01-31           AIR  18.85
# 1                        2013-02-28           AIR  17.57
# 2                        2013-03-31           AIR  18.39
# 3                        2013-04-30           AIR  17.86
# 4                        2013-05-31           AIR  20.06
# ...                             ...           ...    ...
# 140515                   2022-08-31           LYB  83.00
# 140516                   2022-09-30           LYB  75.28
# 140517                   2022-10-31           LYB  76.45
# 140518                   2022-11-30           LYB  85.01
# 140519                   2022-12-31           LYB  83.03
#
#         Shares Outstanding Monthly  Market Capitalization
# 0                       39708000.0           7.484958e+08
# 1                       39708000.0           6.976696e+08
# 2                       39733000.0           7.306899e+08
# 3                       39733000.0           7.096314e+08
# 4                       39733000.0           7.970440e+08
# ...                            ...                    ...
# 140515                 326206000.0           2.707510e+10
# 140516                 326206000.0           2.455679e+10
# 140517                 325624000.0           2.489395e+10
# 140518                 325624000.0           2.768130e+10
# 140519                 325624000.0           2.703656e+10
#
# [140520 rows x 5 columns]

# %%
len(df)/120
# Out:
# 1171.0

# %%
df.to_excel('controls_full_no0\data_filtered_control_size.xlsx')

# %% [markdown]
# <h1>Control Illiquidity</h1>

# %%
"""
Here we create the monthly illiquidity measure for each stock
It takes 3 steps:
- daily returns
- daily volume
- aggregate the daily ratios into monthly measures
""""

# %% [markdown]
# <h4>Daily Returns</h4>

# %%
df = pd.read_csv('controls_full_no0\data_control_volatility.txt', delimiter='\t')
df = df.drop(columns=['gvkey', 'iid']).rename(columns={'datadate': 'Date', 'tic': 'Ticker Symbol', 'prccd': 'Price'})
df
# Out:
# C:\Users\538562gz\AppData\Local\Temp\ipykernel_9528\1721254334.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('controls_full_no0\data_control_volatility.txt', delimiter='\t')
#                Date Ticker Symbol  Price
# 0        2013-01-02           AIR  19.37
# 1        2013-01-03           AIR  19.82
# 2        2013-01-04           AIR  20.11
# 3        2013-01-07           AIR  19.75
# 4        2013-01-08           AIR  19.61
# ...             ...           ...    ...
# 4386105  2022-12-23           FRO  12.49
# 4386106  2022-12-27           FRO  12.48
# 4386107  2022-12-28           FRO  11.92
# 4386108  2022-12-29           FRO  12.06
# 4386109  2022-12-30           FRO  12.14
#
# [4386110 rows x 3 columns]

# %%
df['Daily Returns'] = df.groupby('Ticker Symbol')['Price'].pct_change()*100
df['Date'] = pd.to_datetime(df['Date']) 
daily_returns = df
daily_returns
# Out:
#               Date Ticker Symbol  Price  Daily Returns
# 0       2013-01-02           AIR  19.37            NaN
# 1       2013-01-03           AIR  19.82       2.323180
# 2       2013-01-04           AIR  20.11       1.463169
# 3       2013-01-07           AIR  19.75      -1.790154
# 4       2013-01-08           AIR  19.61      -0.708861
# ...            ...           ...    ...            ...
# 4386105 2022-12-23           FRO  12.49       0.725806
# 4386106 2022-12-27           FRO  12.48      -0.080064
# 4386107 2022-12-28           FRO  11.92      -4.487179
# 4386108 2022-12-29           FRO  12.06       1.174497
# 4386109 2022-12-30           FRO  12.14       0.663350
#
# [4386110 rows x 4 columns]

# %%
daily_returns['Daily Returns'] = daily_returns['Daily Returns'].abs()
daily_returns
# Out:
#               Date Ticker Symbol  Price  Daily Returns
# 0       2013-01-02           AIR  19.37            NaN
# 1       2013-01-03           AIR  19.82       2.323180
# 2       2013-01-04           AIR  20.11       1.463169
# 3       2013-01-07           AIR  19.75       1.790154
# 4       2013-01-08           AIR  19.61       0.708861
# ...            ...           ...    ...            ...
# 4386105 2022-12-23           FRO  12.49       0.725806
# 4386106 2022-12-27           FRO  12.48       0.080064
# 4386107 2022-12-28           FRO  11.92       4.487179
# 4386108 2022-12-29           FRO  12.06       1.174497
# 4386109 2022-12-30           FRO  12.14       0.663350
#
# [4386110 rows x 4 columns]

# %% [markdown]
# <h4>Daily Volume</h4>

# %%
df = pd.read_csv('controls_full_no0\data_control_volume.txt', delimiter='\t')
df
# Out:
# C:\Users\538562gz\AppData\Local\Temp\ipykernel_9528\2527819357.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('controls_full_no0\data_control_volume.txt', delimiter='\t')
#           gvkey iid    datadate  tic     cshtrd
# 0          1004  01  2013-01-02  AIR   427126.0
# 1          1004  01  2013-01-03  AIR   419610.0
# 2          1004  01  2013-01-04  AIR   386724.0
# 3          1004  01  2013-01-07  AIR   303724.0
# 4          1004  01  2013-01-08  AIR   311604.0
# ...         ...  ..         ...  ...        ...
# 4386105  312009  01  2022-12-23  FRO  3959851.0
# 4386106  312009  01  2022-12-27  FRO  1886300.0
# 4386107  312009  01  2022-12-28  FRO  3168506.0
# 4386108  312009  01  2022-12-29  FRO  3568007.0
# 4386109  312009  01  2022-12-30  FRO  4143462.0
#
# [4386110 rows x 5 columns]

# %%
df = df.drop(columns=['gvkey', 'iid']).rename(columns={'datadate': 'Date', 'tic': 'Ticker Symbol', 'cshtrd': 'Volume'})
df['Date'] = pd.to_datetime(df['Date']) 
daily_volume = df
daily_volume
# Out:
#               Date Ticker Symbol     Volume
# 0       2013-01-02           AIR   427126.0
# 1       2013-01-03           AIR   419610.0
# 2       2013-01-04           AIR   386724.0
# 3       2013-01-07           AIR   303724.0
# 4       2013-01-08           AIR   311604.0
# ...            ...           ...        ...
# 4386105 2022-12-23           FRO  3959851.0
# 4386106 2022-12-27           FRO  1886300.0
# 4386107 2022-12-28           FRO  3168506.0
# 4386108 2022-12-29           FRO  3568007.0
# 4386109 2022-12-30           FRO  4143462.0
#
# [4386110 rows x 3 columns]

# %% [markdown]
# <h4>Daily Ratio to Monthly Measures</h4>

# %%
df = pd.merge(daily_returns, daily_volume, on=['Date', 'Ticker Symbol'])
df['Ratio'] = df['Daily Returns'] / df['Volume']
df
# Out:
#               Date Ticker Symbol  Price  Daily Returns     Volume
# 0       2013-01-02           AIR  19.37            NaN   427126.0
# 1       2013-01-03           AIR  19.82       2.323180   419610.0
# 2       2013-01-04           AIR  20.11       1.463169   386724.0
# 3       2013-01-07           AIR  19.75       1.790154   303724.0
# 4       2013-01-08           AIR  19.61       0.708861   311604.0
# ...            ...           ...    ...            ...        ...
# 4386105 2022-12-23           FRO  12.49       0.725806  3959851.0
# 4386106 2022-12-27           FRO  12.48       0.080064  1886300.0
# 4386107 2022-12-28           FRO  11.92       4.487179  3168506.0
# 4386108 2022-12-29           FRO  12.06       1.174497  3568007.0
# 4386109 2022-12-30           FRO  12.14       0.663350  4143462.0
#
# [4386110 rows x 5 columns]

# %%
monthly_illiquidity = df.groupby(['Ticker Symbol', pd.Grouper(key='Date', freq='M')])['Ratio'].mean()
df = monthly_illiquidity.reset_index().rename(columns={'Ratio': 'Illiquidity'})
df
# Out:
# Ticker Symbol  Date
# 0050B          2013-02-28         NaN
#                2013-05-31         NaN
#                2013-08-31         NaN
#                2013-11-30         NaN
#                2014-02-28         NaN
#                                ...
# ZWS            2022-08-31    0.000002
#                2022-09-30    0.000002
#                2022-10-31    0.000002
#                2022-11-30    0.000002
#                2022-12-31    0.000002
# Name: Ratio, Length: 212090, dtype: float64

# %%
df = df[df['Ticker Symbol'].isin(all_stocks)] \
    .groupby('Ticker Symbol') \
    .filter(lambda x: len(x) == 120 and not x.isna().any().any() and not (x['Illiquidity'] == 0).any()) \
    .reset_index() \
    .drop('index', axis=1) 
df
# Out:
#        Ticker Symbol       Date   Illiquidity
# 0                  A 2013-01-31  2.887525e-07
# 1                  A 2013-02-28  2.961422e-07
# 2                  A 2013-03-31  2.901643e-07
# 3                  A 2013-04-30  3.265074e-07
# 4                  A 2013-05-31  2.599894e-07
# ...              ...        ...           ...
# 139555           ZWS 2022-08-31  2.262266e-06
# 139556           ZWS 2022-09-30  1.884943e-06
# 139557           ZWS 2022-10-31  1.792403e-06
# 139558           ZWS 2022-11-30  1.519318e-06
# 139559           ZWS 2022-12-31  1.960707e-06
#
# [139560 rows x 3 columns]

# %%
len(df)/120
# Out:
# 1163.0

# %%
df.to_excel('controls_full_no0\data_filtered_control_illiquidity.xlsx')

# %% [markdown]
# <h1>Control Fluency</h1>

# %%
"""
Create for each stock its fluency variable
"""
df = pd.read_excel('z_predictions_100x.xlsx')
df
# Out:
#      Symbol                         Name      Fluency
# 0         A         Agilent Technologies   622.599854
# 1      AAIC  Arlington Asset Investment    765.885742
# 2       AAP          Advance Auto Parts   1789.879639
# 3       AAT       American Assets Trust   1152.093750
# 4        AB    AllianceBernstein Holding   620.703552
# ...     ...                          ...          ...
# 1188   YELP                        Yelp   1430.900146
# 1189    YPF                         YPF    424.110168
# 1190    YUM                  Yum Brands   2033.593994
# 1191    ZBH      Zimmer Biomet Holdings    424.110168
# 1192    ZWS  Zurn Elkay Water Solutions    424.110168
#
# [1193 rows x 3 columns]

# %%
symbols = df['Symbol']
symbols
# Out:
# 0          A
# 1       AAIC
# 2        AAP
# 3        AAT
# 4         AB
#         ...
# 1188    YELP
# 1189     YPF
# 1190     YUM
# 1191     ZBH
# 1192     ZWS
# Name: Symbol, Length: 1193, dtype: object

# %%
fluency = df['Fluency']
fluency
# Out:
# 0        622.599854
# 1        765.885742
# 2       1789.879639
# 3       1152.093750
# 4        620.703552
#            ...
# 1188    1430.900146
# 1189     424.110168
# 1190    2033.593994
# 1191     424.110168
# 1192     424.110168
# Name: Fluency, Length: 1193, dtype: float64

# %%
repeated_symbols = []
for symbol in symbols:
    repeated_symbols = repeated_symbols + [symbol]*120
    
repeated_symbols
# Out:
# ['A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAIC',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAP',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AAT',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'AB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABB',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABBV',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABC',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  'ABG',
#  ...]

# %%
repeated_fluency = []
for score in fluency:
    repeated_fluency = repeated_fluency + [score]*120
    
repeated_fluency
# Out:
# [622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  622.599853515625,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  765.8857421875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1789.879638671875,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  1152.09375,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  620.7035522460938,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  1169.520751953125,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  622.6113891601562,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  424.1101684570312,
#  ...]

# %%
len(repeated_fluency), type(repeated_fluency)
# Out:
# (143160, list)

# %%
dates = pd.date_range('2013-01-01','2022-12-31', freq='M').tolist()
repeated_dates = dates*1193
repeated_dates
# Out:
# [Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  Timestamp('2016-05-31 00:00:00', freq='M'),
#  Timestamp('2016-06-30 00:00:00', freq='M'),
#  Timestamp('2016-07-31 00:00:00', freq='M'),
#  Timestamp('2016-08-31 00:00:00', freq='M'),
#  Timestamp('2016-09-30 00:00:00', freq='M'),
#  Timestamp('2016-10-31 00:00:00', freq='M'),
#  Timestamp('2016-11-30 00:00:00', freq='M'),
#  Timestamp('2016-12-31 00:00:00', freq='M'),
#  Timestamp('2017-01-31 00:00:00', freq='M'),
#  Timestamp('2017-02-28 00:00:00', freq='M'),
#  Timestamp('2017-03-31 00:00:00', freq='M'),
#  Timestamp('2017-04-30 00:00:00', freq='M'),
#  Timestamp('2017-05-31 00:00:00', freq='M'),
#  Timestamp('2017-06-30 00:00:00', freq='M'),
#  Timestamp('2017-07-31 00:00:00', freq='M'),
#  Timestamp('2017-08-31 00:00:00', freq='M'),
#  Timestamp('2017-09-30 00:00:00', freq='M'),
#  Timestamp('2017-10-31 00:00:00', freq='M'),
#  Timestamp('2017-11-30 00:00:00', freq='M'),
#  Timestamp('2017-12-31 00:00:00', freq='M'),
#  Timestamp('2018-01-31 00:00:00', freq='M'),
#  Timestamp('2018-02-28 00:00:00', freq='M'),
#  Timestamp('2018-03-31 00:00:00', freq='M'),
#  Timestamp('2018-04-30 00:00:00', freq='M'),
#  Timestamp('2018-05-31 00:00:00', freq='M'),
#  Timestamp('2018-06-30 00:00:00', freq='M'),
#  Timestamp('2018-07-31 00:00:00', freq='M'),
#  Timestamp('2018-08-31 00:00:00', freq='M'),
#  Timestamp('2018-09-30 00:00:00', freq='M'),
#  Timestamp('2018-10-31 00:00:00', freq='M'),
#  Timestamp('2018-11-30 00:00:00', freq='M'),
#  Timestamp('2018-12-31 00:00:00', freq='M'),
#  Timestamp('2019-01-31 00:00:00', freq='M'),
#  Timestamp('2019-02-28 00:00:00', freq='M'),
#  Timestamp('2019-03-31 00:00:00', freq='M'),
#  Timestamp('2019-04-30 00:00:00', freq='M'),
#  Timestamp('2019-05-31 00:00:00', freq='M'),
#  Timestamp('2019-06-30 00:00:00', freq='M'),
#  Timestamp('2019-07-31 00:00:00', freq='M'),
#  Timestamp('2019-08-31 00:00:00', freq='M'),
#  Timestamp('2019-09-30 00:00:00', freq='M'),
#  Timestamp('2019-10-31 00:00:00', freq='M'),
#  Timestamp('2019-11-30 00:00:00', freq='M'),
#  Timestamp('2019-12-31 00:00:00', freq='M'),
#  Timestamp('2020-01-31 00:00:00', freq='M'),
#  Timestamp('2020-02-29 00:00:00', freq='M'),
#  Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M'),
#  Timestamp('2020-12-31 00:00:00', freq='M'),
#  Timestamp('2021-01-31 00:00:00', freq='M'),
#  Timestamp('2021-02-28 00:00:00', freq='M'),
#  Timestamp('2021-03-31 00:00:00', freq='M'),
#  Timestamp('2021-04-30 00:00:00', freq='M'),
#  Timestamp('2021-05-31 00:00:00', freq='M'),
#  Timestamp('2021-06-30 00:00:00', freq='M'),
#  Timestamp('2021-07-31 00:00:00', freq='M'),
#  Timestamp('2021-08-31 00:00:00', freq='M'),
#  Timestamp('2021-09-30 00:00:00', freq='M'),
#  Timestamp('2021-10-31 00:00:00', freq='M'),
#  Timestamp('2021-11-30 00:00:00', freq='M'),
#  Timestamp('2021-12-31 00:00:00', freq='M'),
#  Timestamp('2022-01-31 00:00:00', freq='M'),
#  Timestamp('2022-02-28 00:00:00', freq='M'),
#  Timestamp('2022-03-31 00:00:00', freq='M'),
#  Timestamp('2022-04-30 00:00:00', freq='M'),
#  Timestamp('2022-05-31 00:00:00', freq='M'),
#  Timestamp('2022-06-30 00:00:00', freq='M'),
#  Timestamp('2022-07-31 00:00:00', freq='M'),
#  Timestamp('2022-08-31 00:00:00', freq='M'),
#  Timestamp('2022-09-30 00:00:00', freq='M'),
#  Timestamp('2022-10-31 00:00:00', freq='M'),
#  Timestamp('2022-11-30 00:00:00', freq='M'),
#  Timestamp('2022-12-31 00:00:00', freq='M'),
#  Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  Timestamp('2016-05-31 00:00:00', freq='M'),
#  Timestamp('2016-06-30 00:00:00', freq='M'),
#  Timestamp('2016-07-31 00:00:00', freq='M'),
#  Timestamp('2016-08-31 00:00:00', freq='M'),
#  Timestamp('2016-09-30 00:00:00', freq='M'),
#  Timestamp('2016-10-31 00:00:00', freq='M'),
#  Timestamp('2016-11-30 00:00:00', freq='M'),
#  Timestamp('2016-12-31 00:00:00', freq='M'),
#  Timestamp('2017-01-31 00:00:00', freq='M'),
#  Timestamp('2017-02-28 00:00:00', freq='M'),
#  Timestamp('2017-03-31 00:00:00', freq='M'),
#  Timestamp('2017-04-30 00:00:00', freq='M'),
#  Timestamp('2017-05-31 00:00:00', freq='M'),
#  Timestamp('2017-06-30 00:00:00', freq='M'),
#  Timestamp('2017-07-31 00:00:00', freq='M'),
#  Timestamp('2017-08-31 00:00:00', freq='M'),
#  Timestamp('2017-09-30 00:00:00', freq='M'),
#  Timestamp('2017-10-31 00:00:00', freq='M'),
#  Timestamp('2017-11-30 00:00:00', freq='M'),
#  Timestamp('2017-12-31 00:00:00', freq='M'),
#  Timestamp('2018-01-31 00:00:00', freq='M'),
#  Timestamp('2018-02-28 00:00:00', freq='M'),
#  Timestamp('2018-03-31 00:00:00', freq='M'),
#  Timestamp('2018-04-30 00:00:00', freq='M'),
#  Timestamp('2018-05-31 00:00:00', freq='M'),
#  Timestamp('2018-06-30 00:00:00', freq='M'),
#  Timestamp('2018-07-31 00:00:00', freq='M'),
#  Timestamp('2018-08-31 00:00:00', freq='M'),
#  Timestamp('2018-09-30 00:00:00', freq='M'),
#  Timestamp('2018-10-31 00:00:00', freq='M'),
#  Timestamp('2018-11-30 00:00:00', freq='M'),
#  Timestamp('2018-12-31 00:00:00', freq='M'),
#  Timestamp('2019-01-31 00:00:00', freq='M'),
#  Timestamp('2019-02-28 00:00:00', freq='M'),
#  Timestamp('2019-03-31 00:00:00', freq='M'),
#  Timestamp('2019-04-30 00:00:00', freq='M'),
#  Timestamp('2019-05-31 00:00:00', freq='M'),
#  Timestamp('2019-06-30 00:00:00', freq='M'),
#  Timestamp('2019-07-31 00:00:00', freq='M'),
#  Timestamp('2019-08-31 00:00:00', freq='M'),
#  Timestamp('2019-09-30 00:00:00', freq='M'),
#  Timestamp('2019-10-31 00:00:00', freq='M'),
#  Timestamp('2019-11-30 00:00:00', freq='M'),
#  Timestamp('2019-12-31 00:00:00', freq='M'),
#  Timestamp('2020-01-31 00:00:00', freq='M'),
#  Timestamp('2020-02-29 00:00:00', freq='M'),
#  Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M'),
#  Timestamp('2020-12-31 00:00:00', freq='M'),
#  Timestamp('2021-01-31 00:00:00', freq='M'),
#  Timestamp('2021-02-28 00:00:00', freq='M'),
#  Timestamp('2021-03-31 00:00:00', freq='M'),
#  Timestamp('2021-04-30 00:00:00', freq='M'),
#  Timestamp('2021-05-31 00:00:00', freq='M'),
#  Timestamp('2021-06-30 00:00:00', freq='M'),
#  Timestamp('2021-07-31 00:00:00', freq='M'),
#  Timestamp('2021-08-31 00:00:00', freq='M'),
#  Timestamp('2021-09-30 00:00:00', freq='M'),
#  Timestamp('2021-10-31 00:00:00', freq='M'),
#  Timestamp('2021-11-30 00:00:00', freq='M'),
#  Timestamp('2021-12-31 00:00:00', freq='M'),
#  Timestamp('2022-01-31 00:00:00', freq='M'),
#  Timestamp('2022-02-28 00:00:00', freq='M'),
#  Timestamp('2022-03-31 00:00:00', freq='M'),
#  Timestamp('2022-04-30 00:00:00', freq='M'),
#  Timestamp('2022-05-31 00:00:00', freq='M'),
#  Timestamp('2022-06-30 00:00:00', freq='M'),
#  Timestamp('2022-07-31 00:00:00', freq='M'),
#  Timestamp('2022-08-31 00:00:00', freq='M'),
#  Timestamp('2022-09-30 00:00:00', freq='M'),
#  Timestamp('2022-10-31 00:00:00', freq='M'),
#  Timestamp('2022-11-30 00:00:00', freq='M'),
#  Timestamp('2022-12-31 00:00:00', freq='M'),
#  Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  Timestamp('2016-05-31 00:00:00', freq='M'),
#  Timestamp('2016-06-30 00:00:00', freq='M'),
#  Timestamp('2016-07-31 00:00:00', freq='M'),
#  Timestamp('2016-08-31 00:00:00', freq='M'),
#  Timestamp('2016-09-30 00:00:00', freq='M'),
#  Timestamp('2016-10-31 00:00:00', freq='M'),
#  Timestamp('2016-11-30 00:00:00', freq='M'),
#  Timestamp('2016-12-31 00:00:00', freq='M'),
#  Timestamp('2017-01-31 00:00:00', freq='M'),
#  Timestamp('2017-02-28 00:00:00', freq='M'),
#  Timestamp('2017-03-31 00:00:00', freq='M'),
#  Timestamp('2017-04-30 00:00:00', freq='M'),
#  Timestamp('2017-05-31 00:00:00', freq='M'),
#  Timestamp('2017-06-30 00:00:00', freq='M'),
#  Timestamp('2017-07-31 00:00:00', freq='M'),
#  Timestamp('2017-08-31 00:00:00', freq='M'),
#  Timestamp('2017-09-30 00:00:00', freq='M'),
#  Timestamp('2017-10-31 00:00:00', freq='M'),
#  Timestamp('2017-11-30 00:00:00', freq='M'),
#  Timestamp('2017-12-31 00:00:00', freq='M'),
#  Timestamp('2018-01-31 00:00:00', freq='M'),
#  Timestamp('2018-02-28 00:00:00', freq='M'),
#  Timestamp('2018-03-31 00:00:00', freq='M'),
#  Timestamp('2018-04-30 00:00:00', freq='M'),
#  Timestamp('2018-05-31 00:00:00', freq='M'),
#  Timestamp('2018-06-30 00:00:00', freq='M'),
#  Timestamp('2018-07-31 00:00:00', freq='M'),
#  Timestamp('2018-08-31 00:00:00', freq='M'),
#  Timestamp('2018-09-30 00:00:00', freq='M'),
#  Timestamp('2018-10-31 00:00:00', freq='M'),
#  Timestamp('2018-11-30 00:00:00', freq='M'),
#  Timestamp('2018-12-31 00:00:00', freq='M'),
#  Timestamp('2019-01-31 00:00:00', freq='M'),
#  Timestamp('2019-02-28 00:00:00', freq='M'),
#  Timestamp('2019-03-31 00:00:00', freq='M'),
#  Timestamp('2019-04-30 00:00:00', freq='M'),
#  Timestamp('2019-05-31 00:00:00', freq='M'),
#  Timestamp('2019-06-30 00:00:00', freq='M'),
#  Timestamp('2019-07-31 00:00:00', freq='M'),
#  Timestamp('2019-08-31 00:00:00', freq='M'),
#  Timestamp('2019-09-30 00:00:00', freq='M'),
#  Timestamp('2019-10-31 00:00:00', freq='M'),
#  Timestamp('2019-11-30 00:00:00', freq='M'),
#  Timestamp('2019-12-31 00:00:00', freq='M'),
#  Timestamp('2020-01-31 00:00:00', freq='M'),
#  Timestamp('2020-02-29 00:00:00', freq='M'),
#  Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M'),
#  Timestamp('2020-12-31 00:00:00', freq='M'),
#  Timestamp('2021-01-31 00:00:00', freq='M'),
#  Timestamp('2021-02-28 00:00:00', freq='M'),
#  Timestamp('2021-03-31 00:00:00', freq='M'),
#  Timestamp('2021-04-30 00:00:00', freq='M'),
#  Timestamp('2021-05-31 00:00:00', freq='M'),
#  Timestamp('2021-06-30 00:00:00', freq='M'),
#  Timestamp('2021-07-31 00:00:00', freq='M'),
#  Timestamp('2021-08-31 00:00:00', freq='M'),
#  Timestamp('2021-09-30 00:00:00', freq='M'),
#  Timestamp('2021-10-31 00:00:00', freq='M'),
#  Timestamp('2021-11-30 00:00:00', freq='M'),
#  Timestamp('2021-12-31 00:00:00', freq='M'),
#  Timestamp('2022-01-31 00:00:00', freq='M'),
#  Timestamp('2022-02-28 00:00:00', freq='M'),
#  Timestamp('2022-03-31 00:00:00', freq='M'),
#  Timestamp('2022-04-30 00:00:00', freq='M'),
#  Timestamp('2022-05-31 00:00:00', freq='M'),
#  Timestamp('2022-06-30 00:00:00', freq='M'),
#  Timestamp('2022-07-31 00:00:00', freq='M'),
#  Timestamp('2022-08-31 00:00:00', freq='M'),
#  Timestamp('2022-09-30 00:00:00', freq='M'),
#  Timestamp('2022-10-31 00:00:00', freq='M'),
#  Timestamp('2022-11-30 00:00:00', freq='M'),
#  Timestamp('2022-12-31 00:00:00', freq='M'),
#  Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  Timestamp('2016-05-31 00:00:00', freq='M'),
#  Timestamp('2016-06-30 00:00:00', freq='M'),
#  Timestamp('2016-07-31 00:00:00', freq='M'),
#  Timestamp('2016-08-31 00:00:00', freq='M'),
#  Timestamp('2016-09-30 00:00:00', freq='M'),
#  Timestamp('2016-10-31 00:00:00', freq='M'),
#  Timestamp('2016-11-30 00:00:00', freq='M'),
#  Timestamp('2016-12-31 00:00:00', freq='M'),
#  Timestamp('2017-01-31 00:00:00', freq='M'),
#  Timestamp('2017-02-28 00:00:00', freq='M'),
#  Timestamp('2017-03-31 00:00:00', freq='M'),
#  Timestamp('2017-04-30 00:00:00', freq='M'),
#  Timestamp('2017-05-31 00:00:00', freq='M'),
#  Timestamp('2017-06-30 00:00:00', freq='M'),
#  Timestamp('2017-07-31 00:00:00', freq='M'),
#  Timestamp('2017-08-31 00:00:00', freq='M'),
#  Timestamp('2017-09-30 00:00:00', freq='M'),
#  Timestamp('2017-10-31 00:00:00', freq='M'),
#  Timestamp('2017-11-30 00:00:00', freq='M'),
#  Timestamp('2017-12-31 00:00:00', freq='M'),
#  Timestamp('2018-01-31 00:00:00', freq='M'),
#  Timestamp('2018-02-28 00:00:00', freq='M'),
#  Timestamp('2018-03-31 00:00:00', freq='M'),
#  Timestamp('2018-04-30 00:00:00', freq='M'),
#  Timestamp('2018-05-31 00:00:00', freq='M'),
#  Timestamp('2018-06-30 00:00:00', freq='M'),
#  Timestamp('2018-07-31 00:00:00', freq='M'),
#  Timestamp('2018-08-31 00:00:00', freq='M'),
#  Timestamp('2018-09-30 00:00:00', freq='M'),
#  Timestamp('2018-10-31 00:00:00', freq='M'),
#  Timestamp('2018-11-30 00:00:00', freq='M'),
#  Timestamp('2018-12-31 00:00:00', freq='M'),
#  Timestamp('2019-01-31 00:00:00', freq='M'),
#  Timestamp('2019-02-28 00:00:00', freq='M'),
#  Timestamp('2019-03-31 00:00:00', freq='M'),
#  Timestamp('2019-04-30 00:00:00', freq='M'),
#  Timestamp('2019-05-31 00:00:00', freq='M'),
#  Timestamp('2019-06-30 00:00:00', freq='M'),
#  Timestamp('2019-07-31 00:00:00', freq='M'),
#  Timestamp('2019-08-31 00:00:00', freq='M'),
#  Timestamp('2019-09-30 00:00:00', freq='M'),
#  Timestamp('2019-10-31 00:00:00', freq='M'),
#  Timestamp('2019-11-30 00:00:00', freq='M'),
#  Timestamp('2019-12-31 00:00:00', freq='M'),
#  Timestamp('2020-01-31 00:00:00', freq='M'),
#  Timestamp('2020-02-29 00:00:00', freq='M'),
#  Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M'),
#  Timestamp('2020-12-31 00:00:00', freq='M'),
#  Timestamp('2021-01-31 00:00:00', freq='M'),
#  Timestamp('2021-02-28 00:00:00', freq='M'),
#  Timestamp('2021-03-31 00:00:00', freq='M'),
#  Timestamp('2021-04-30 00:00:00', freq='M'),
#  Timestamp('2021-05-31 00:00:00', freq='M'),
#  Timestamp('2021-06-30 00:00:00', freq='M'),
#  Timestamp('2021-07-31 00:00:00', freq='M'),
#  Timestamp('2021-08-31 00:00:00', freq='M'),
#  Timestamp('2021-09-30 00:00:00', freq='M'),
#  Timestamp('2021-10-31 00:00:00', freq='M'),
#  Timestamp('2021-11-30 00:00:00', freq='M'),
#  Timestamp('2021-12-31 00:00:00', freq='M'),
#  Timestamp('2022-01-31 00:00:00', freq='M'),
#  Timestamp('2022-02-28 00:00:00', freq='M'),
#  Timestamp('2022-03-31 00:00:00', freq='M'),
#  Timestamp('2022-04-30 00:00:00', freq='M'),
#  Timestamp('2022-05-31 00:00:00', freq='M'),
#  Timestamp('2022-06-30 00:00:00', freq='M'),
#  Timestamp('2022-07-31 00:00:00', freq='M'),
#  Timestamp('2022-08-31 00:00:00', freq='M'),
#  Timestamp('2022-09-30 00:00:00', freq='M'),
#  Timestamp('2022-10-31 00:00:00', freq='M'),
#  Timestamp('2022-11-30 00:00:00', freq='M'),
#  Timestamp('2022-12-31 00:00:00', freq='M'),
#  Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  Timestamp('2016-05-31 00:00:00', freq='M'),
#  Timestamp('2016-06-30 00:00:00', freq='M'),
#  Timestamp('2016-07-31 00:00:00', freq='M'),
#  Timestamp('2016-08-31 00:00:00', freq='M'),
#  Timestamp('2016-09-30 00:00:00', freq='M'),
#  Timestamp('2016-10-31 00:00:00', freq='M'),
#  Timestamp('2016-11-30 00:00:00', freq='M'),
#  Timestamp('2016-12-31 00:00:00', freq='M'),
#  Timestamp('2017-01-31 00:00:00', freq='M'),
#  Timestamp('2017-02-28 00:00:00', freq='M'),
#  Timestamp('2017-03-31 00:00:00', freq='M'),
#  Timestamp('2017-04-30 00:00:00', freq='M'),
#  Timestamp('2017-05-31 00:00:00', freq='M'),
#  Timestamp('2017-06-30 00:00:00', freq='M'),
#  Timestamp('2017-07-31 00:00:00', freq='M'),
#  Timestamp('2017-08-31 00:00:00', freq='M'),
#  Timestamp('2017-09-30 00:00:00', freq='M'),
#  Timestamp('2017-10-31 00:00:00', freq='M'),
#  Timestamp('2017-11-30 00:00:00', freq='M'),
#  Timestamp('2017-12-31 00:00:00', freq='M'),
#  Timestamp('2018-01-31 00:00:00', freq='M'),
#  Timestamp('2018-02-28 00:00:00', freq='M'),
#  Timestamp('2018-03-31 00:00:00', freq='M'),
#  Timestamp('2018-04-30 00:00:00', freq='M'),
#  Timestamp('2018-05-31 00:00:00', freq='M'),
#  Timestamp('2018-06-30 00:00:00', freq='M'),
#  Timestamp('2018-07-31 00:00:00', freq='M'),
#  Timestamp('2018-08-31 00:00:00', freq='M'),
#  Timestamp('2018-09-30 00:00:00', freq='M'),
#  Timestamp('2018-10-31 00:00:00', freq='M'),
#  Timestamp('2018-11-30 00:00:00', freq='M'),
#  Timestamp('2018-12-31 00:00:00', freq='M'),
#  Timestamp('2019-01-31 00:00:00', freq='M'),
#  Timestamp('2019-02-28 00:00:00', freq='M'),
#  Timestamp('2019-03-31 00:00:00', freq='M'),
#  Timestamp('2019-04-30 00:00:00', freq='M'),
#  Timestamp('2019-05-31 00:00:00', freq='M'),
#  Timestamp('2019-06-30 00:00:00', freq='M'),
#  Timestamp('2019-07-31 00:00:00', freq='M'),
#  Timestamp('2019-08-31 00:00:00', freq='M'),
#  Timestamp('2019-09-30 00:00:00', freq='M'),
#  Timestamp('2019-10-31 00:00:00', freq='M'),
#  Timestamp('2019-11-30 00:00:00', freq='M'),
#  Timestamp('2019-12-31 00:00:00', freq='M'),
#  Timestamp('2020-01-31 00:00:00', freq='M'),
#  Timestamp('2020-02-29 00:00:00', freq='M'),
#  Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M'),
#  Timestamp('2020-12-31 00:00:00', freq='M'),
#  Timestamp('2021-01-31 00:00:00', freq='M'),
#  Timestamp('2021-02-28 00:00:00', freq='M'),
#  Timestamp('2021-03-31 00:00:00', freq='M'),
#  Timestamp('2021-04-30 00:00:00', freq='M'),
#  Timestamp('2021-05-31 00:00:00', freq='M'),
#  Timestamp('2021-06-30 00:00:00', freq='M'),
#  Timestamp('2021-07-31 00:00:00', freq='M'),
#  Timestamp('2021-08-31 00:00:00', freq='M'),
#  Timestamp('2021-09-30 00:00:00', freq='M'),
#  Timestamp('2021-10-31 00:00:00', freq='M'),
#  Timestamp('2021-11-30 00:00:00', freq='M'),
#  Timestamp('2021-12-31 00:00:00', freq='M'),
#  Timestamp('2022-01-31 00:00:00', freq='M'),
#  Timestamp('2022-02-28 00:00:00', freq='M'),
#  Timestamp('2022-03-31 00:00:00', freq='M'),
#  Timestamp('2022-04-30 00:00:00', freq='M'),
#  Timestamp('2022-05-31 00:00:00', freq='M'),
#  Timestamp('2022-06-30 00:00:00', freq='M'),
#  Timestamp('2022-07-31 00:00:00', freq='M'),
#  Timestamp('2022-08-31 00:00:00', freq='M'),
#  Timestamp('2022-09-30 00:00:00', freq='M'),
#  Timestamp('2022-10-31 00:00:00', freq='M'),
#  Timestamp('2022-11-30 00:00:00', freq='M'),
#  Timestamp('2022-12-31 00:00:00', freq='M'),
#  Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  Timestamp('2016-05-31 00:00:00', freq='M'),
#  Timestamp('2016-06-30 00:00:00', freq='M'),
#  Timestamp('2016-07-31 00:00:00', freq='M'),
#  Timestamp('2016-08-31 00:00:00', freq='M'),
#  Timestamp('2016-09-30 00:00:00', freq='M'),
#  Timestamp('2016-10-31 00:00:00', freq='M'),
#  Timestamp('2016-11-30 00:00:00', freq='M'),
#  Timestamp('2016-12-31 00:00:00', freq='M'),
#  Timestamp('2017-01-31 00:00:00', freq='M'),
#  Timestamp('2017-02-28 00:00:00', freq='M'),
#  Timestamp('2017-03-31 00:00:00', freq='M'),
#  Timestamp('2017-04-30 00:00:00', freq='M'),
#  Timestamp('2017-05-31 00:00:00', freq='M'),
#  Timestamp('2017-06-30 00:00:00', freq='M'),
#  Timestamp('2017-07-31 00:00:00', freq='M'),
#  Timestamp('2017-08-31 00:00:00', freq='M'),
#  Timestamp('2017-09-30 00:00:00', freq='M'),
#  Timestamp('2017-10-31 00:00:00', freq='M'),
#  Timestamp('2017-11-30 00:00:00', freq='M'),
#  Timestamp('2017-12-31 00:00:00', freq='M'),
#  Timestamp('2018-01-31 00:00:00', freq='M'),
#  Timestamp('2018-02-28 00:00:00', freq='M'),
#  Timestamp('2018-03-31 00:00:00', freq='M'),
#  Timestamp('2018-04-30 00:00:00', freq='M'),
#  Timestamp('2018-05-31 00:00:00', freq='M'),
#  Timestamp('2018-06-30 00:00:00', freq='M'),
#  Timestamp('2018-07-31 00:00:00', freq='M'),
#  Timestamp('2018-08-31 00:00:00', freq='M'),
#  Timestamp('2018-09-30 00:00:00', freq='M'),
#  Timestamp('2018-10-31 00:00:00', freq='M'),
#  Timestamp('2018-11-30 00:00:00', freq='M'),
#  Timestamp('2018-12-31 00:00:00', freq='M'),
#  Timestamp('2019-01-31 00:00:00', freq='M'),
#  Timestamp('2019-02-28 00:00:00', freq='M'),
#  Timestamp('2019-03-31 00:00:00', freq='M'),
#  Timestamp('2019-04-30 00:00:00', freq='M'),
#  Timestamp('2019-05-31 00:00:00', freq='M'),
#  Timestamp('2019-06-30 00:00:00', freq='M'),
#  Timestamp('2019-07-31 00:00:00', freq='M'),
#  Timestamp('2019-08-31 00:00:00', freq='M'),
#  Timestamp('2019-09-30 00:00:00', freq='M'),
#  Timestamp('2019-10-31 00:00:00', freq='M'),
#  Timestamp('2019-11-30 00:00:00', freq='M'),
#  Timestamp('2019-12-31 00:00:00', freq='M'),
#  Timestamp('2020-01-31 00:00:00', freq='M'),
#  Timestamp('2020-02-29 00:00:00', freq='M'),
#  Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M'),
#  Timestamp('2020-12-31 00:00:00', freq='M'),
#  Timestamp('2021-01-31 00:00:00', freq='M'),
#  Timestamp('2021-02-28 00:00:00', freq='M'),
#  Timestamp('2021-03-31 00:00:00', freq='M'),
#  Timestamp('2021-04-30 00:00:00', freq='M'),
#  Timestamp('2021-05-31 00:00:00', freq='M'),
#  Timestamp('2021-06-30 00:00:00', freq='M'),
#  Timestamp('2021-07-31 00:00:00', freq='M'),
#  Timestamp('2021-08-31 00:00:00', freq='M'),
#  Timestamp('2021-09-30 00:00:00', freq='M'),
#  Timestamp('2021-10-31 00:00:00', freq='M'),
#  Timestamp('2021-11-30 00:00:00', freq='M'),
#  Timestamp('2021-12-31 00:00:00', freq='M'),
#  Timestamp('2022-01-31 00:00:00', freq='M'),
#  Timestamp('2022-02-28 00:00:00', freq='M'),
#  Timestamp('2022-03-31 00:00:00', freq='M'),
#  Timestamp('2022-04-30 00:00:00', freq='M'),
#  Timestamp('2022-05-31 00:00:00', freq='M'),
#  Timestamp('2022-06-30 00:00:00', freq='M'),
#  Timestamp('2022-07-31 00:00:00', freq='M'),
#  Timestamp('2022-08-31 00:00:00', freq='M'),
#  Timestamp('2022-09-30 00:00:00', freq='M'),
#  Timestamp('2022-10-31 00:00:00', freq='M'),
#  Timestamp('2022-11-30 00:00:00', freq='M'),
#  Timestamp('2022-12-31 00:00:00', freq='M'),
#  Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  Timestamp('2016-05-31 00:00:00', freq='M'),
#  Timestamp('2016-06-30 00:00:00', freq='M'),
#  Timestamp('2016-07-31 00:00:00', freq='M'),
#  Timestamp('2016-08-31 00:00:00', freq='M'),
#  Timestamp('2016-09-30 00:00:00', freq='M'),
#  Timestamp('2016-10-31 00:00:00', freq='M'),
#  Timestamp('2016-11-30 00:00:00', freq='M'),
#  Timestamp('2016-12-31 00:00:00', freq='M'),
#  Timestamp('2017-01-31 00:00:00', freq='M'),
#  Timestamp('2017-02-28 00:00:00', freq='M'),
#  Timestamp('2017-03-31 00:00:00', freq='M'),
#  Timestamp('2017-04-30 00:00:00', freq='M'),
#  Timestamp('2017-05-31 00:00:00', freq='M'),
#  Timestamp('2017-06-30 00:00:00', freq='M'),
#  Timestamp('2017-07-31 00:00:00', freq='M'),
#  Timestamp('2017-08-31 00:00:00', freq='M'),
#  Timestamp('2017-09-30 00:00:00', freq='M'),
#  Timestamp('2017-10-31 00:00:00', freq='M'),
#  Timestamp('2017-11-30 00:00:00', freq='M'),
#  Timestamp('2017-12-31 00:00:00', freq='M'),
#  Timestamp('2018-01-31 00:00:00', freq='M'),
#  Timestamp('2018-02-28 00:00:00', freq='M'),
#  Timestamp('2018-03-31 00:00:00', freq='M'),
#  Timestamp('2018-04-30 00:00:00', freq='M'),
#  Timestamp('2018-05-31 00:00:00', freq='M'),
#  Timestamp('2018-06-30 00:00:00', freq='M'),
#  Timestamp('2018-07-31 00:00:00', freq='M'),
#  Timestamp('2018-08-31 00:00:00', freq='M'),
#  Timestamp('2018-09-30 00:00:00', freq='M'),
#  Timestamp('2018-10-31 00:00:00', freq='M'),
#  Timestamp('2018-11-30 00:00:00', freq='M'),
#  Timestamp('2018-12-31 00:00:00', freq='M'),
#  Timestamp('2019-01-31 00:00:00', freq='M'),
#  Timestamp('2019-02-28 00:00:00', freq='M'),
#  Timestamp('2019-03-31 00:00:00', freq='M'),
#  Timestamp('2019-04-30 00:00:00', freq='M'),
#  Timestamp('2019-05-31 00:00:00', freq='M'),
#  Timestamp('2019-06-30 00:00:00', freq='M'),
#  Timestamp('2019-07-31 00:00:00', freq='M'),
#  Timestamp('2019-08-31 00:00:00', freq='M'),
#  Timestamp('2019-09-30 00:00:00', freq='M'),
#  Timestamp('2019-10-31 00:00:00', freq='M'),
#  Timestamp('2019-11-30 00:00:00', freq='M'),
#  Timestamp('2019-12-31 00:00:00', freq='M'),
#  Timestamp('2020-01-31 00:00:00', freq='M'),
#  Timestamp('2020-02-29 00:00:00', freq='M'),
#  Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M'),
#  Timestamp('2020-12-31 00:00:00', freq='M'),
#  Timestamp('2021-01-31 00:00:00', freq='M'),
#  Timestamp('2021-02-28 00:00:00', freq='M'),
#  Timestamp('2021-03-31 00:00:00', freq='M'),
#  Timestamp('2021-04-30 00:00:00', freq='M'),
#  Timestamp('2021-05-31 00:00:00', freq='M'),
#  Timestamp('2021-06-30 00:00:00', freq='M'),
#  Timestamp('2021-07-31 00:00:00', freq='M'),
#  Timestamp('2021-08-31 00:00:00', freq='M'),
#  Timestamp('2021-09-30 00:00:00', freq='M'),
#  Timestamp('2021-10-31 00:00:00', freq='M'),
#  Timestamp('2021-11-30 00:00:00', freq='M'),
#  Timestamp('2021-12-31 00:00:00', freq='M'),
#  Timestamp('2022-01-31 00:00:00', freq='M'),
#  Timestamp('2022-02-28 00:00:00', freq='M'),
#  Timestamp('2022-03-31 00:00:00', freq='M'),
#  Timestamp('2022-04-30 00:00:00', freq='M'),
#  Timestamp('2022-05-31 00:00:00', freq='M'),
#  Timestamp('2022-06-30 00:00:00', freq='M'),
#  Timestamp('2022-07-31 00:00:00', freq='M'),
#  Timestamp('2022-08-31 00:00:00', freq='M'),
#  Timestamp('2022-09-30 00:00:00', freq='M'),
#  Timestamp('2022-10-31 00:00:00', freq='M'),
#  Timestamp('2022-11-30 00:00:00', freq='M'),
#  Timestamp('2022-12-31 00:00:00', freq='M'),
#  Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  Timestamp('2016-05-31 00:00:00', freq='M'),
#  Timestamp('2016-06-30 00:00:00', freq='M'),
#  Timestamp('2016-07-31 00:00:00', freq='M'),
#  Timestamp('2016-08-31 00:00:00', freq='M'),
#  Timestamp('2016-09-30 00:00:00', freq='M'),
#  Timestamp('2016-10-31 00:00:00', freq='M'),
#  Timestamp('2016-11-30 00:00:00', freq='M'),
#  Timestamp('2016-12-31 00:00:00', freq='M'),
#  Timestamp('2017-01-31 00:00:00', freq='M'),
#  Timestamp('2017-02-28 00:00:00', freq='M'),
#  Timestamp('2017-03-31 00:00:00', freq='M'),
#  Timestamp('2017-04-30 00:00:00', freq='M'),
#  Timestamp('2017-05-31 00:00:00', freq='M'),
#  Timestamp('2017-06-30 00:00:00', freq='M'),
#  Timestamp('2017-07-31 00:00:00', freq='M'),
#  Timestamp('2017-08-31 00:00:00', freq='M'),
#  Timestamp('2017-09-30 00:00:00', freq='M'),
#  Timestamp('2017-10-31 00:00:00', freq='M'),
#  Timestamp('2017-11-30 00:00:00', freq='M'),
#  Timestamp('2017-12-31 00:00:00', freq='M'),
#  Timestamp('2018-01-31 00:00:00', freq='M'),
#  Timestamp('2018-02-28 00:00:00', freq='M'),
#  Timestamp('2018-03-31 00:00:00', freq='M'),
#  Timestamp('2018-04-30 00:00:00', freq='M'),
#  Timestamp('2018-05-31 00:00:00', freq='M'),
#  Timestamp('2018-06-30 00:00:00', freq='M'),
#  Timestamp('2018-07-31 00:00:00', freq='M'),
#  Timestamp('2018-08-31 00:00:00', freq='M'),
#  Timestamp('2018-09-30 00:00:00', freq='M'),
#  Timestamp('2018-10-31 00:00:00', freq='M'),
#  Timestamp('2018-11-30 00:00:00', freq='M'),
#  Timestamp('2018-12-31 00:00:00', freq='M'),
#  Timestamp('2019-01-31 00:00:00', freq='M'),
#  Timestamp('2019-02-28 00:00:00', freq='M'),
#  Timestamp('2019-03-31 00:00:00', freq='M'),
#  Timestamp('2019-04-30 00:00:00', freq='M'),
#  Timestamp('2019-05-31 00:00:00', freq='M'),
#  Timestamp('2019-06-30 00:00:00', freq='M'),
#  Timestamp('2019-07-31 00:00:00', freq='M'),
#  Timestamp('2019-08-31 00:00:00', freq='M'),
#  Timestamp('2019-09-30 00:00:00', freq='M'),
#  Timestamp('2019-10-31 00:00:00', freq='M'),
#  Timestamp('2019-11-30 00:00:00', freq='M'),
#  Timestamp('2019-12-31 00:00:00', freq='M'),
#  Timestamp('2020-01-31 00:00:00', freq='M'),
#  Timestamp('2020-02-29 00:00:00', freq='M'),
#  Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M'),
#  Timestamp('2020-12-31 00:00:00', freq='M'),
#  Timestamp('2021-01-31 00:00:00', freq='M'),
#  Timestamp('2021-02-28 00:00:00', freq='M'),
#  Timestamp('2021-03-31 00:00:00', freq='M'),
#  Timestamp('2021-04-30 00:00:00', freq='M'),
#  Timestamp('2021-05-31 00:00:00', freq='M'),
#  Timestamp('2021-06-30 00:00:00', freq='M'),
#  Timestamp('2021-07-31 00:00:00', freq='M'),
#  Timestamp('2021-08-31 00:00:00', freq='M'),
#  Timestamp('2021-09-30 00:00:00', freq='M'),
#  Timestamp('2021-10-31 00:00:00', freq='M'),
#  Timestamp('2021-11-30 00:00:00', freq='M'),
#  Timestamp('2021-12-31 00:00:00', freq='M'),
#  Timestamp('2022-01-31 00:00:00', freq='M'),
#  Timestamp('2022-02-28 00:00:00', freq='M'),
#  Timestamp('2022-03-31 00:00:00', freq='M'),
#  Timestamp('2022-04-30 00:00:00', freq='M'),
#  Timestamp('2022-05-31 00:00:00', freq='M'),
#  Timestamp('2022-06-30 00:00:00', freq='M'),
#  Timestamp('2022-07-31 00:00:00', freq='M'),
#  Timestamp('2022-08-31 00:00:00', freq='M'),
#  Timestamp('2022-09-30 00:00:00', freq='M'),
#  Timestamp('2022-10-31 00:00:00', freq='M'),
#  Timestamp('2022-11-30 00:00:00', freq='M'),
#  Timestamp('2022-12-31 00:00:00', freq='M'),
#  Timestamp('2013-01-31 00:00:00', freq='M'),
#  Timestamp('2013-02-28 00:00:00', freq='M'),
#  Timestamp('2013-03-31 00:00:00', freq='M'),
#  Timestamp('2013-04-30 00:00:00', freq='M'),
#  Timestamp('2013-05-31 00:00:00', freq='M'),
#  Timestamp('2013-06-30 00:00:00', freq='M'),
#  Timestamp('2013-07-31 00:00:00', freq='M'),
#  Timestamp('2013-08-31 00:00:00', freq='M'),
#  Timestamp('2013-09-30 00:00:00', freq='M'),
#  Timestamp('2013-10-31 00:00:00', freq='M'),
#  Timestamp('2013-11-30 00:00:00', freq='M'),
#  Timestamp('2013-12-31 00:00:00', freq='M'),
#  Timestamp('2014-01-31 00:00:00', freq='M'),
#  Timestamp('2014-02-28 00:00:00', freq='M'),
#  Timestamp('2014-03-31 00:00:00', freq='M'),
#  Timestamp('2014-04-30 00:00:00', freq='M'),
#  Timestamp('2014-05-31 00:00:00', freq='M'),
#  Timestamp('2014-06-30 00:00:00', freq='M'),
#  Timestamp('2014-07-31 00:00:00', freq='M'),
#  Timestamp('2014-08-31 00:00:00', freq='M'),
#  Timestamp('2014-09-30 00:00:00', freq='M'),
#  Timestamp('2014-10-31 00:00:00', freq='M'),
#  Timestamp('2014-11-30 00:00:00', freq='M'),
#  Timestamp('2014-12-31 00:00:00', freq='M'),
#  Timestamp('2015-01-31 00:00:00', freq='M'),
#  Timestamp('2015-02-28 00:00:00', freq='M'),
#  Timestamp('2015-03-31 00:00:00', freq='M'),
#  Timestamp('2015-04-30 00:00:00', freq='M'),
#  Timestamp('2015-05-31 00:00:00', freq='M'),
#  Timestamp('2015-06-30 00:00:00', freq='M'),
#  Timestamp('2015-07-31 00:00:00', freq='M'),
#  Timestamp('2015-08-31 00:00:00', freq='M'),
#  Timestamp('2015-09-30 00:00:00', freq='M'),
#  Timestamp('2015-10-31 00:00:00', freq='M'),
#  Timestamp('2015-11-30 00:00:00', freq='M'),
#  Timestamp('2015-12-31 00:00:00', freq='M'),
#  Timestamp('2016-01-31 00:00:00', freq='M'),
#  Timestamp('2016-02-29 00:00:00', freq='M'),
#  Timestamp('2016-03-31 00:00:00', freq='M'),
#  Timestamp('2016-04-30 00:00:00', freq='M'),
#  ...]

# %%
len(repeated_dates)
# Out:
# 143160

# %%
repeated_df = pd.DataFrame({'Ticker Symbol': repeated_symbols, 'Date': repeated_dates, 'Fluency': repeated_fluency})
repeated_df
# Out:
#        Ticker Symbol       Date     Fluency
# 0                  A 2013-01-31  622.599854
# 1                  A 2013-02-28  622.599854
# 2                  A 2013-03-31  622.599854
# 3                  A 2013-04-30  622.599854
# 4                  A 2013-05-31  622.599854
# ...              ...        ...         ...
# 143155           ZWS 2022-08-31  424.110168
# 143156           ZWS 2022-09-30  424.110168
# 143157           ZWS 2022-10-31  424.110168
# 143158           ZWS 2022-11-30  424.110168
# 143159           ZWS 2022-12-31  424.110168
#
# [143160 rows x 3 columns]

# %%
repeated_df.to_excel('controls_full_no0\data_filtered_control_fluency.xlsx')

# %% [markdown]
# <h1>Merging Controls</h1>

# %%
"""
Merge all control dfs into one big df, which is used in a regression
This is done for each characteristic
"""
# Out:
# '\nMerge all control dfs into one big df, which is used in a regression\nThis is done for each characteristic\n'

# %%
book_to_market = pd.read_excel('controls_full_no0\data_filtered_control_bm.xlsx')
book_to_market
# Out:
#             Date  Book/Market Ticker Symbol
# 0     2013-01-31     0.542476          AMRC
# 1     2013-02-28     0.646842          AMRC
# 2     2013-03-31     0.646842          AMRC
# 3     2013-04-30     0.646842          AMRC
# 4     2013-05-31     0.854068          AMRC
# ...          ...          ...           ...
# 74755 2022-08-31     0.732472           VPG
# 74756 2022-09-30     0.732472           VPG
# 74757 2022-10-31     0.732472           VPG
# 74758 2022-11-30     0.724565           VPG
# 74759 2022-12-31     0.724565           VPG
#
# [74760 rows x 3 columns]

# %%
ps = pd.read_excel('controls_full_no0\data_filtered_control_ps.xlsx')
ps
# Out:
#             Date  Price/Sales Ticker Symbol
# 0     2013-01-31     4.515576          ORCL
# 1     2013-02-28     4.340010          ORCL
# 2     2013-03-31     4.090668          ORCL
# 3     2013-04-30     4.145753          ORCL
# 4     2013-05-31     4.224659          ORCL
# ...          ...          ...           ...
# 81595 2022-08-31     1.244434           VPG
# 81596 2022-09-30     1.073238           VPG
# 81597 2022-10-31     1.224122           VPG
# 81598 2022-11-30     1.428888           VPG
# 81599 2022-12-31     1.361265           VPG
#
# [81600 rows x 3 columns]

# %%
profitability = pd.read_excel('controls_full_no0\data_filtered_control_profitability.xlsx')
profitability
# Out:
#             Date  Gross Profit/Total Assets Ticker Symbol
# 0     2013-01-31                   0.391929          ORCL
# 1     2013-02-28                   0.391929          ORCL
# 2     2013-03-31                   0.391929          ORCL
# 3     2013-04-30                   0.387195          ORCL
# 4     2013-05-31                   0.387195          ORCL
# ...          ...                        ...           ...
# 81475 2022-08-31                   0.352589           VPG
# 81476 2022-09-30                   0.352589           VPG
# 81477 2022-10-31                   0.352589           VPG
# 81478 2022-11-30                   0.361082           VPG
# 81479 2022-12-31                   0.361082           VPG
#
# [81480 rows x 3 columns]

# %%
asset_turnover = pd.read_excel('controls_full_no0\data_filtered_control_asset_turnover.xlsx')
asset_turnover
# Out:
#             Date  Asset Turnover Ticker Symbol
# 0     2013-01-31        0.482093          ORCL
# 1     2013-02-28        0.482093          ORCL
# 2     2013-03-31        0.482093          ORCL
# 3     2013-04-30        0.473248          ORCL
# 4     2013-05-31        0.473248          ORCL
# ...          ...             ...           ...
# 80755 2022-08-31        0.762084           VPG
# 80756 2022-09-30        0.762084           VPG
# 80757 2022-10-31        0.762084           VPG
# 80758 2022-11-30        0.777952           VPG
# 80759 2022-12-31        0.777952           VPG
#
# [80760 rows x 3 columns]

# %%
rd = pd.read_excel('controls_full_no0\data_filtered_control_rd.xlsx')
rd
# Out:
#             Date  Research and Development/Sales Ticker Symbol
# 0     2013-01-31                        0.128149          ORCL
# 1     2013-02-28                        0.128149          ORCL
# 2     2013-03-31                        0.128149          ORCL
# 3     2013-04-30                        0.129532          ORCL
# 4     2013-05-31                        0.129532          ORCL
# ...          ...                             ...           ...
# 27955 2022-08-31                        0.152131          CALX
# 27956 2022-09-30                        0.152131          CALX
# 27957 2022-10-31                        0.152131          CALX
# 27958 2022-11-30                        0.149277          CALX
# 27959 2022-12-31                        0.149277          CALX
#
# [27960 rows x 3 columns]

# %%
advertising = pd.read_excel('controls_full_no0\data_filtered_control_advertising.xlsx')
advertising
# Out:
#             Date  Avertising Expenses/Sales Ticker Symbol
# 0     2013-01-31                   0.002128          ORCL
# 1     2013-02-28                   0.002128          ORCL
# 2     2013-03-31                   0.002128          ORCL
# 3     2013-04-30                   0.002128          ORCL
# 4     2013-05-31                   0.002128          ORCL
# ...          ...                        ...           ...
# 28075 2022-08-31                   0.037243           SIX
# 28076 2022-09-30                   0.037243           SIX
# 28077 2022-10-31                   0.037243           SIX
# 28078 2022-11-30                   0.037243           SIX
# 28079 2022-12-31                   0.037243           SIX
#
# [28080 rows x 3 columns]

# %%
leverage = pd.read_excel('controls_full_no0\data_filtered_control_leverage.xlsx')
leverage
# Out:
#             Date  Total Debt/Total Assets Ticker Symbol
# 0     2013-01-31                 0.212944          ORCL
# 1     2013-02-28                 0.212944          ORCL
# 2     2013-03-31                 0.212944          ORCL
# 3     2013-04-30                 0.225337          ORCL
# 4     2013-05-31                 0.225337          ORCL
# ...          ...                      ...           ...
# 73315 2022-08-31                 0.194819           VPG
# 73316 2022-09-30                 0.194819           VPG
# 73317 2022-10-31                 0.194819           VPG
# 73318 2022-11-30                 0.192046           VPG
# 73319 2022-12-31                 0.192046           VPG
#
# [73320 rows x 3 columns]

# %%
size = pd.read_excel('controls_full_no0\data_filtered_control_size.xlsx')
size
# Out:
#        Ticker Symbol       Date  Market Capitalization
# 0                AIR 2013-01-31           7.484958e+08
# 1                AIR 2013-02-28           6.976696e+08
# 2                AIR 2013-03-31           7.306899e+08
# 3                AIR 2013-04-30           7.096314e+08
# 4                AIR 2013-05-31           7.970440e+08
# ...              ...        ...                    ...
# 140515           LYB 2022-08-31           2.707510e+10
# 140516           LYB 2022-09-30           2.455679e+10
# 140517           LYB 2022-10-31           2.489395e+10
# 140518           LYB 2022-11-30           2.768130e+10
# 140519           LYB 2022-12-31           2.703656e+10
#
# [140520 rows x 3 columns]

# %%
price = pd.read_excel('controls_full_no0\data_filtered_control_price.xlsx')
price
# Out:
#              Date  Price - Close - Monthly Ticker Symbol
# 0      2013-01-31                 0.053050           AIR
# 1      2013-02-28                 0.056915           AIR
# 2      2013-03-31                 0.054377           AIR
# 3      2013-04-30                 0.055991           AIR
# 4      2013-05-31                 0.049850           AIR
# ...           ...                      ...           ...
# 140875 2022-08-31                 0.012048           LYB
# 140876 2022-09-30                 0.013284           LYB
# 140877 2022-10-31                 0.013080           LYB
# 140878 2022-11-30                 0.011763           LYB
# 140879 2022-12-31                 0.012044           LYB
#
# [140880 rows x 3 columns]

# %%
volatility = pd.read_excel('controls_full_no0\data_filtered_control_volatility.xlsx')
volatility
# Out:
#        Ticker Symbol       Date  Monthly Volatility
# 0                  A 2013-01-31            1.094107
# 1                  A 2013-02-28            1.662541
# 2                  A 2013-03-31            1.118800
# 3                  A 2013-04-30            1.841820
# 4                  A 2013-05-31            1.359981
# ...              ...        ...                 ...
# 140755           ZWS 2022-08-31            2.072921
# 140756           ZWS 2022-09-30            2.119668
# 140757           ZWS 2022-10-31            3.310613
# 140758           ZWS 2022-11-30            2.658288
# 140759           ZWS 2022-12-31            2.876602
#
# [140760 rows x 3 columns]

# %%
fluency = pd.read_excel('controls_full_no0\data_filtered_control_fluency.xlsx')
fluency
# Out:
#        Ticker Symbol       Date     Fluency
# 0                  A 2013-01-31  622.599854
# 1                  A 2013-02-28  622.599854
# 2                  A 2013-03-31  622.599854
# 3                  A 2013-04-30  622.599854
# 4                  A 2013-05-31  622.599854
# ...              ...        ...         ...
# 143155           ZWS 2022-08-31  424.110168
# 143156           ZWS 2022-09-30  424.110168
# 143157           ZWS 2022-10-31  424.110168
# 143158           ZWS 2022-11-30  424.110168
# 143159           ZWS 2022-12-31  424.110168
#
# [143160 rows x 3 columns]

# %%
illiquidity = pd.read_excel('controls_full_no0/data_filtered_control_illiquidity.xlsx')
illiquidity
# Out:
#        Ticker Symbol       Date   Illiquidity
# 0                  A 2013-01-31  2.887525e-07
# 1                  A 2013-02-28  2.961422e-07
# 2                  A 2013-03-31  2.901643e-07
# 3                  A 2013-04-30  3.265074e-07
# 4                  A 2013-05-31  2.599894e-07
# ...              ...        ...           ...
# 139555           ZWS 2022-08-31  2.262266e-06
# 139556           ZWS 2022-09-30  1.884943e-06
# 139557           ZWS 2022-10-31  1.792403e-06
# 139558           ZWS 2022-11-30  1.519318e-06
# 139559           ZWS 2022-12-31  1.960707e-06
#
# [139560 rows x 3 columns]

# %%
returns = pd.read_excel('controls_full_no0/data_filtered_control_return.xlsx')
returns
# Out:
#        Ticker Symbol       Date  Monthly Total Return
# 0                AIR 2013-01-31              1.311563
# 1                AIR 2013-02-28             -6.790451
# 2                AIR 2013-03-31              4.667046
# 3                AIR 2013-04-30             -2.474171
# 4                AIR 2013-05-31             12.318029
# ...              ...        ...                   ...
# 114115           LYB 2022-08-31             -5.531867
# 114116           LYB 2022-09-30             -9.301205
# 114117           LYB 2022-10-31              1.554198
# 114118           LYB 2022-11-30             12.753434
# 114119           LYB 2022-12-31             -2.329138
#
# [114120 rows x 3 columns]

# %% [markdown]
# <h4>Performance</h4>

# %%
# merging for performance
results_performance = pd.merge(returns, fluency, on=['Date', 'Ticker Symbol'])

# %%
len(results_performance)/120
# Out:
# 951.0

# %%
results_performance
# Out:
#        Ticker Symbol       Date  Monthly Total Return     Fluency
# 0                AIR 2013-01-31              1.311563  424.110168
# 1                AIR 2013-02-28             -6.790451  424.110168
# 2                AIR 2013-03-31              4.667046  424.110168
# 3                AIR 2013-04-30             -2.474171  424.110168
# 4                AIR 2013-05-31             12.318029  424.110168
# ...              ...        ...                   ...         ...
# 114115           LYB 2022-08-31             -5.531867  424.110168
# 114116           LYB 2022-09-30             -9.301205  424.110168
# 114117           LYB 2022-10-31              1.554198  424.110168
# 114118           LYB 2022-11-30             12.753434  424.110168
# 114119           LYB 2022-12-31             -2.329138  424.110168
#
# [114120 rows x 4 columns]

# %%
results_performance.to_excel('controls_full_no0/data_reg_performance.xlsx')

# %% [markdown]
# <h4>Illiquidity</h4>

# %%
results_illiquidity = pd.merge(illiquidity, fluency, on=['Date', 'Ticker Symbol'])
results_illiquidity = pd.merge(results_illiquidity, size, on=['Date', 'Ticker Symbol'])
results_illiquidity = pd.merge(results_illiquidity, profitability, on=['Date', 'Ticker Symbol'])
results_illiquidity = pd.merge(results_illiquidity, book_to_market, on=['Date', 'Ticker Symbol'])
results_illiquidity = pd.merge(results_illiquidity, advertising, on=['Date', 'Ticker Symbol'])
results_illiquidity = pd.merge(results_illiquidity, price, on=['Date', 'Ticker Symbol'])
results_illiquidity = pd.merge(results_illiquidity, volatility, on=['Date', 'Ticker Symbol'])

len(results_illiquidity)/120
# Out:
# 202.0

# %%
results_illiquidity
# Out:
#       Ticker Symbol       Date   Illiquidity      Fluency  \
# 0                 A 2013-01-31  2.887525e-07   622.599854
# 1                 A 2013-02-28  2.961422e-07   622.599854
# 2                 A 2013-03-31  2.901643e-07   622.599854
# 3                 A 2013-04-30  3.265074e-07   622.599854
# 4                 A 2013-05-31  2.599894e-07   622.599854
# ...             ...        ...           ...          ...
# 24235          YELP 2022-08-31  2.562980e-06  1430.900146
# 24236          YELP 2022-09-30  2.407408e-06  1430.900146
# 24237          YELP 2022-10-31  2.303998e-06  1430.900146
# 24238          YELP 2022-11-30  2.498737e-06  1430.900146
# 24239          YELP 2022-12-31  2.269227e-06  1430.900146
#
#        Market Capitalization  Gross Profit/Total Assets  Book/Market  \
# 0               1.558053e+10                   0.376044     0.431852
# 1               1.439223e+10                   0.376044     0.431852
# 2               1.457026e+10                   0.396045     0.344016
# 3               1.438627e+10                   0.396045     0.344016
# 4               1.577838e+10                   0.396045     0.344016
# ...                      ...                        ...          ...
# 24235           2.401263e+09                   0.974274     0.363855
# 24236           2.382991e+09                   0.974274     0.363855
# 24237           2.699224e+09                   0.974274     0.363855
# 24238           2.157277e+09                   1.018609     0.293804
# 24239           1.905653e+09                   1.018609     0.293804
#
#        Avertising Expenses/Sales  Price - Close - Monthly  Monthly Volatility
# 0                       0.007291                 0.022331            1.094107
# 1                       0.007291                 0.024108            1.662541
# 2                       0.007291                 0.023827            1.118800
# 3                       0.007291                 0.024131            1.841820
# 4                       0.007291                 0.022002            1.359981
# ...                          ...                      ...                 ...
# 24235                   0.054563                 0.029265            4.356689
# 24236                   0.054563                 0.029490            1.981414
# 24237                   0.054563                 0.026035            1.812760
# 24238                   0.054563                 0.032310            4.234128
# 24239                   0.054563                 0.036576            2.008797
#
# [24240 rows x 10 columns]

# %%
results_illiquidity.to_excel('controls_full_no0/data_reg_illiquidity.xlsx')

# %% [markdown]
# <h4>Valuation</h4>

# %%
results_valuation = pd.merge(book_to_market, fluency, on=['Date', 'Ticker Symbol'])
results_valuation = pd.merge(results_valuation, ps, on=['Date', 'Ticker Symbol'])
results_valuation = pd.merge(results_valuation, profitability, on=['Date', 'Ticker Symbol'])
results_valuation = pd.merge(results_valuation, leverage, on=['Date', 'Ticker Symbol'])
results_valuation = pd.merge(results_valuation, advertising, on=['Date', 'Ticker Symbol'])

len(results_valuation)/120
# Out:
# 167.0

# %%
results_valuation
# Out:
#             Date  Book/Market Ticker Symbol      Fluency  Price/Sales  \
# 0     2013-01-31     0.133712            BC   622.776367     0.880432
# 1     2013-02-28     0.065353            BC   622.776367     0.883946
# 2     2013-03-31     0.065353            BC   622.776367     0.832497
# 3     2013-04-30     0.065353            BC   622.776367     0.770218
# 4     2013-05-31     0.073331            BC   622.776367     0.809050
# ...          ...          ...           ...          ...          ...
# 20035 2022-08-31     0.006457          EXPR  1198.341064     0.071124
# 20036 2022-09-30     0.006457          EXPR  1198.341064     0.055062
# 20037 2022-10-31     0.006457          EXPR  1198.341064     0.052945
# 20038 2022-11-30     0.006457          EXPR  1198.341064     0.049571
# 20039 2022-12-31     0.006457          EXPR  1198.341064     0.046493
#
#        Gross Profit/Total Assets  Total Debt/Total Assets  \
# 0                       0.399588                 0.263404
# 1                       0.426532                 0.235872
# 2                       0.426532                 0.235872
# 3                       0.426532                 0.235872
# 4                       0.416177                 0.242719
# ...                          ...                      ...
# 20035                   0.533481                 0.715633
# 20036                   0.544412                 0.706854
# 20037                   0.544412                 0.706854
# 20038                   0.544412                 0.706854
# 20039                   0.525322                 0.713792
#
#        Avertising Expenses/Sales
# 0                       0.009578
# 1                       0.009280
# 2                       0.009280
# 3                       0.009280
# 4                       0.009280
# ...                          ...
# 20035                   0.072181
# 20036                   0.072181
# 20037                   0.072181
# 20038                   0.072181
# 20039                   0.072181
#
# [20040 rows x 8 columns]

# %%
results_valuation.to_excel('controls_full_no0/data_reg_valuation.xlsx')
