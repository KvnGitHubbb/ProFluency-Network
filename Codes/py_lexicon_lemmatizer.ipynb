# %% [markdown]
# <span style="color:red;">Lemmatize the lexicon</span>

# %%
# !pip install nltk

# %%
import nltk 
import re
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import words

import pandas as pd
import numpy as np

# %%
nltk.download("wordnet")
nltk.download('words')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kzhg1\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\kzhg1\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kzhg1\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# <h1>Load Lexicon</h1>

# %%
def only_az_chars(string):
    return bool(re.match('^[a-z]+$', string))

# %%
words.fileids()
# Out:
# ['en', 'en-basic']

# %%
lexicon = words.words('en')
lexicon = pd.DataFrame(lexicon)
lexicon
# Out:
#                  0
# 0                A
# 1                a
# 2               aa
# 3              aal
# 4            aalii
# ...            ...
# 235881      zythem
# 235882      Zythia
# 235883      zythum
# 235884     Zyzomys
# 235885  Zyzzogeton
#
# [235886 rows x 1 columns]

# %% [markdown]
# <h1>Lemmatization</h1>

# %%
lemmatizer = WordNetLemmatizer()

# %%
# step 1
lexicon = lexicon[0].str.lower()

# %%
# step 2
for i in range(0,len(lexicon)):
    string = lemmatizer.lemmatize(lexicon[i])               #lemmatizer.lemmatize("a")
    lexicon[i] = string

# %%
# step 3
lexicon = np.unique(lexicon)
lexicon
len(lexicon)
# Out:
# 233444

# %%
lexicon = lexicon.tolist()
lexicon
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
# ...

# %%
allow = [string for string in lexicon if only_az_chars(string)]
allow
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
# ...

# %%
len(allow)
# Out:
# 233442

# %%
pd.DataFrame(allow).to_excel("data_lexicon.xlsx")
