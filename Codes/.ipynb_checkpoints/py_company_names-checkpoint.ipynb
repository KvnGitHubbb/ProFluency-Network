# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('data_nyse_screener.xlsx', 'sheet2')
data
# Out:
#      Symbol                         Name  IPO Year                  Sector  \
# 0         A        Agilent Technologies     1999.0             Industrials
# 1      AAIC  Arlington Asset Investment        NaN             Real Estate
# 2       AAP          Advance Auto Parts        NaN  Consumer Discretionary
# 3       AAT       American Assets Trust     2011.0             Real Estate
# 4        AB    AllianceBernstein Holding       NaN                 Finance
# ...     ...                          ...       ...                     ...
# 1189   YELP                        Yelp     2012.0              Technology
# 1190    YPF                         YPF     1993.0                  Energy
# 1191    YUM                  Yum Brands        NaN  Consumer Discretionary
# 1192    ZBH      Zimmer Biomet Holdings        NaN             Health Care
# 1193    ZWS  Zurn Elkay Water Solutions     2012.0               Utilities
#
#                                Industry;
# ...

# %%
data.to_csv("z_test.txt", columns=["Symbol"], header=False, index=False)
